# %%
import pandas as pd
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# read csv file using pandas
df = pd.read_csv('/content/drive/MyDrive/0.MKCE/Datasets/insurance_data.csv')

# %%
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
#histogram continous data
import matplotlib.pyplot as plt

plt.hist(df['age'])
plt.show()
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f2929cbd2d0>,
# ...
#       dtype=object)

# %%
# bar chart (for categorical data)

plt.bar(df['bought_insurance'],height=df['age'])
# Out:
# <BarContainer object of 27 artists>

# %%
#box plot (plt can use only one column)

plt.boxplot(df['age'])
plt.show()

plt.boxplot(df['bought_insurance'])
plt.show()

# %%
#seaborn (it is the built on plt and can use more than one columns)

import seaborn as sns

sns.boxplot(df['age'],df['bought_insurance'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.model_selection import train_test_split

# %%
x=df['age']
y=df['bought_insurance']

x=x.values
x=x.reshape(-1,1)
x.shape

y=y.values

# %%
type(x)
# Out:
# numpy.ndarray

# %%
type(y)
# Out:
# numpy.ndarray

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=123)

# %%
print(x_test.shape)
print(x_train.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (6, 1)
# (21, 1)
# (21,)
# (6,)

# %%
#logistic regression 
from sklearn.linear_model import LogisticRegression

model=LogisticRegression()

model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
#prediction

y_pred=model.predict(x_test)

y_pred
# Out:
# array([1, 1, 1, 1, 1, 0])

# %%
# probability of occurence 1 or 0 in place of corresponding x_test values
model.predict_proba(x_test)
# Out:
# array([[0.37419393, 0.62580607],
#        [0.14458251, 0.85541749],
#        [0.09646069, 0.90353931],
#        [0.07821097, 0.92178903],
#        [0.25188723, 0.74811277],
#        [0.80820269, 0.19179731]])

# %%
x_test
# Out:
# array([[45],
#        [56],
#        [60],
#        [62],
#        [50],
#        [28]])

# %%
#to measure accuracy of model

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1, 0],
#        [0, 5]])

# %%
a=classification_report(y_test,y_pred)
print(a)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         1
#            1       1.00      1.00      1.00         5
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6
